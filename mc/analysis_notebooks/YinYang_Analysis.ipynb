# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
df_learn = pd.read_csv("../experiments/yinyang/df_learn.csv")
df_runtime = pd.read_csv("../experiments/yinyang/df_runtime.csv")

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))

sns.lineplot((df_learn[(df_learn["Method"] == "Random Feedback") * (df_learn["Model"] == "Spike")]),
             x="Epoch", y="Accuracy", hue="Sim ID", ax=ax[0])#, units="Sim ID", estimator=None)

#sns.lineplot(df_learn[df_learn["Method"] == "Random Feedback"],
#             x="Epoch", y="Accuracy", hue="Model", ax=ax[0])#, units="Sim ID", estimator=None)

ax[0].legend()
ax[0].set_title("Random Feedback", loc="left")
ax[0].set_ylim(top=1.025)

sns.lineplot(df_learn[df_learn["Method"] == "Feedback Align"],
             x="Epoch", y="Accuracy", hue="Model", ax=ax[1])#, units="Sim ID", estimator=None)

ax[1].legend()
ax[1].set_title("Feedback Align", loc="left")
ax[1].set_ylim(top=1.025)

sns.barplot(data=df_runtime, x="Method",
            hue="Model", y="Runtime", ax=ax[2])

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_learn[(df_learn.Epoch == 1000)*(df_learn.Method=="Random Feedback")*(df_learn["Model"] == "Spike")]
# Out:
#       Epoch  Sim ID  Accuracy      Loss  Model           Method
# 190  1000.0       0  0.937500  0.045309  Spike  Random Feedback
# 191  1000.0       1  0.934896  0.048228  Spike  Random Feedback
# 192  1000.0       2  0.585938  0.214105  Spike  Random Feedback
# 193  1000.0       3  0.834635  0.088471  Spike  Random Feedback
# 194  1000.0       4  0.850260  0.083203  Spike  Random Feedback
# 195  1000.0       5  0.906250  0.053031  Spike  Random Feedback
# 196  1000.0       6  0.889323  0.063584  Spike  Random Feedback
# 197  1000.0       7  0.915365  0.059580  Spike  Random Feedback
# 198  1000.0       8  0.928385  0.051020  Spike  Random Feedback
# 199  1000.0       9  0.329427  0.219463  Spike  Random Feedback
